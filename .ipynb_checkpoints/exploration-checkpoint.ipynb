# %%
import pandas as pd
import numpy as np
import reverse_geocoder as rg

# %%
crimes = pd.read_csv("/Users/Khanna/Downloads/crime_cleaned_parth.csv")

# %%
calls = np.load("/Users/Khanna/Downloads/cleaned_data.npy")
calls = pd.DataFrame(calls)

# %%
calls.columns = ['Type', 'Category', 'DateTime', 'Approach','Borough']

# %%
def timeOfDay(time):
  if(time==None):
    return "other"
  time = int(time)
  if(time>=21 or time <=4):
    return "nuit"
  if(time>=5 and time <=12):
    return "jour"
  if(time>=13 and time <=20):
    return "soir"

# %%
df['Date'], df['Time'] = df['DateTime'].str.split('T', 1).str
del df['DateTime']
df['Time'] = (df['Time'].str[:2])
df[:10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DateTime'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-bde9739ed440> in <module>
# ----> 1 df['Date'], df['Time'] = df['DateTime'].str.split('T', 1).str
#       2 del df['DateTime']
#       3 df['Time'] = (df['Time'].str[:2])
#       4 df[:10]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DateTime'

# %%
crimes[:10]
# Out:
#    Unnamed: 0                         CATEGORIE        DATE QUART   PDQ  \
# 0           0          Vol de véhicule à moteur  2018-09-13  jour  30.0
# 1           1          Vol de véhicule à moteur  2018-04-30  jour  30.0
# 2           2          Vol de véhicule à moteur  2018-09-01  nuit   7.0
# 3           3                            Méfait  2017-07-21  jour  21.0
# 4           4                            Méfait  2017-07-29  jour  12.0
# 5           5          Vol de véhicule à moteur  2017-07-30  nuit  21.0
# 6           6                            Méfait  2017-07-30  jour  38.0
# 7           7                    Vols qualifiés  2017-07-30  jour  21.0
# 8           8  Vol dans / sur véhicule à moteur  2017-08-01  jour  39.0
# 9           9                            Méfait  2017-08-01  jour  21.0
#
#    LONGITUDE   LATITUDE
# 0 -73.626778  45.567780
# 1 -73.626778  45.567780
# 2 -73.685928  45.519122
# 3   1.000000   1.000000
# 4   1.000000   1.000000
# 5   1.000000   1.000000
# 6 -73.591457  45.516776
# 7   1.000000   1.000000
# 8 -73.635117  45.602873
# 9   1.000000   1.000000

# %%
coordinates = (45.567780, -73.626778)
results = rg.search(coordinates)
print(results)
# Out:
# [OrderedDict([('lat', '45.58773'), ('lon', '-73.59501'), ('name', 'Saint-Leonard'), ('admin1', 'Quebec'), ('admin2', 'Montreal'), ('cc', 'CA')])]

# %%
del
# Out:
#             Unnamed: 0  CATEGORIE   DATE  QUART    PDQ  LATITUDE
# LONGITUDE
